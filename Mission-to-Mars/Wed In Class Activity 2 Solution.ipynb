# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
 url = "https://globalvoices.org/page/2/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
browser.links.find_by_partial_text("No thanks").click()

# %%
articles_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    main_area = soup.find("div", class_="post-archive-container")
    articles = main_area.find_all("div", class_="gv-promo-card-text")
    
    for article in articles:
        header = article.find("h3", class_="post-title").text.strip()
        date = article.find("span", class_="datestamp")["title"]
        date = date.replace('_', '')
        
        
        summary_dict = {
            "header": header,
            "date": date
        }
        articles_list.append(summary_dict)

# %%
 for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text("Older").click()

# %%
 articles_list
# Out:
# [{'header': "France's institutional fear of multilingualism: An interview with language activist Michel Feltin-Palas",
#   'date': '30 12 2022'},
#  {'header': 'European Parliament’s Report on Pegasus spyware indicates involvement of North Macedonia companies',
#   'date': '29 12 2022'},
#  {'header': 'Welcome the new year with these joyful traditions from Latin America',
#   'date': '29 12 2022'},
#  {'header': 'A Buryat voice calling on Russia to decolonize : Interview with Instagrammer Seseg Jigjitova',
#   'date': '29 12 2022'},
#  {'header': 'The year in review: What the Caribbean looked like in 2022',
#   'date': '29 12 2022'},
#  {'header': "Trinidad & Tobago's calypsonian Black Stalin, the quintessential ‘Caribbean Man,’ dies at 81",
#   'date': '28 12 2022'},
#  {'header': "Turkey's Saturday Mothers, 27 years on, are still searching for justice and closure",
#   'date': '27 12 2022'},
#  {'header': 'How Morocco’s Atlas Lions made history at the 2022 World Cup',
#   'date': '27 12 2022'},
#  {'header': "Inside my bounty: Raghda's journey", 'date': '27 12 2022'},
#  {'header': "For school New Year's Eve parties in Moscow, some music is apparently deemed inappropriate",
#   'date': '27 12 2022'},
#  {'header': 'Self-taught Trinidadian photographer Jason C. Audain pushes boundaries with the use of AI',
#   'date': '27 12 2022'},
#  {'header': 'The Dutch state apologises for slavery, and the Caribbean wonders: Will reparations follow?',
#   'date': '26 12 2022'},
#  {'header': 'Climate change, digital authoritarianism and disinformation campaigns ruled in South Asia in 2022',
#   'date': '26 12 2022'},
#  {'header': "‘The Balkans are Europe's Latin America in many beautiful ways,’ says Albanian writer",
#   'date': '25 12 2022'},
#  {'header': 'This online game exposes the dangers of deep-sea mining',
#   'date': '25 12 2022'},
#  {'header': 'Classical dance pushes the bounds of traditional gender identities in Cambodia',
#   'date': '24 12 2022'},
#  {'header': 'Turkey, a year in review: Battling both at home and abroad',
#   'date': '24 12 2022'},
#  {'header': "Police in Azerbaijan detain protesters on the day of activist's trial",
#   'date': '24 12 2022'},
#  {'header': 'Governments are still free to use the Pegasus software without human rights safeguards in place',
#   'date': '23 12 2022'},
#  {'header': 'Pundits say unblocking the Lachin Corridor is the only way to avoid humanitarian crisis',
#   'date': '23 12 2022'},
#  {'header': 'Another attack on LGBTQ+ center in Podgorica highlights the need to protect human rights in Montenegro',
#   'date': '23 12 2022'},
#  {'header': 'Documentary about the 1920s Volga famine is prohibited in Russia but broadcasted on YouTube',
#   'date': '22 12 2022'},
#  {'header': 'Transgender women are despised, like the Virgin Mary in her day',
#   'date': '22 12 2022'},
#  {'header': 'Undertones in Afghanistan: ‘Taliban 2.0,’ Women, Resistance',
#   'date': '21 12 2022'},
#  {'header': 'A fact-check of India’s socio-political undercurrents: the case of Zubair',
#   'date': '21 12 2022'},
#  {'header': "Woman dubbed ‘Messi's grandma’ goes viral in Argentina following World Cup win",
#   'date': '21 12 2022'},
#  {'header': "Art curator Mark Pereira's murder during a home invasion leaves Trinbagonian netizens nervous about crime",
#   'date': '21 12 2022'},
#  {'header': "What is Hong Kong role in Russia's sanction evasion?",
#   'date': '21 12 2022'},
#  {'header': 'Australia explores ways to combat widespread greenwashing of carbon emissions',
#   'date': '20 12 2022'},
#  {'header': 'Hong Kong launches a national security legal battle against media tycoon Jimmy Lai',
#   'date': '20 12 2022'},
#  {'header': 'The Venezuelan diaspora in London seeks ways to save lives in Venezuela',
#   'date': '19 12 2022'},
#  {'header': 'Cartoonist Kianoush Ramazani: Hope in Iran during turbulent times',
#   'date': '19 12 2022'},
#  {'header': 'No good news for media freedom in Kyrgyzstan as government arrests journalists, activists, and bloggers',
#   'date': '19 12 2022'},
#  {'header': 'The climate crisis is a water crisis in the Himalayas',
#   'date': '19 12 2022'},
#  {'header': 'Addressing the changing nature of Twitter and emerging social media landscape',
#   'date': '19 12 2022'},
#  {'header': 'World Bank land giveaway in Cambodia marred by problems',
#   'date': '19 12 2022'},
#  {'header': 'Why does South America not seem to care about corruption issues in the World Cup?',
#   'date': '18 12 2022'},
#  {'header': "Did 2022 see the Caribbean become more ‘gay-friendly'?",
#   'date': '18 12 2022'},
#  {'header': 'Twitter Space:  What’s next for the Aragalaya movement in Sri Lanka?',
#   'date': '18 12 2022'},
#  {'header': 'Call to Action on International Migrants Day: Stop forced labour and restore workers’ agency',
#   'date': '18 12 2022'},
#  {'header': "In the midst of Trinidad & Tobago's parang season, calypsonian Singing Francine passes on",
#   'date': '17 12 2022'},
#  {'header': 'What did the outside world in the 1930s know about the Soviet famine and the ‘Holodomor’ in Ukraine?',
#   'date': '16 12 2022'},
#  {'header': 'Data privacy rights advance in Tanzania under new law, but obstacles remain',
#   'date': '16 12 2022'},
#  {'header': "The journey of Trinidad's parang music, in one informative podcast",
#   'date': '16 12 2022'},
#  {'header': "Violence reached an unprecedented level in Brazil's 2022 election, says survey",
#   'date': '15 12 2022'},
#  {'header': 'The climate crisis and the environment in Central Asia — Is there hope?',
#   'date': '15 12 2022'},
#  {'header': 'Russia is waging an information war in Latin America',
#   'date': '15 12 2022'},
#  {'header': "Indonesia's new penal code revisions don't just threaten sexual freedoms",
#   'date': '15 12 2022'},
#  {'header': 'Former president of Georgia facing health problems',
#   'date': '15 12 2022'},
#  {'header': 'In Turkey, local court hands popular mayor a jail sentence',
#   'date': '15 12 2022'},
#  {'header': 'Colmena: an open source media platform connecting Indigenous and rural communities',
#   'date': '14 12 2022'},
#  {'header': 'Hong Kong national anthem mixup causes chaos at international sporting events',
#   'date': '13 12 2022'},
#  {'header': 'The effects of internet shutdowns on public mobilization',
#   'date': '13 12 2022'},
#  {'header': 'Rasha Azab and her friends: Seven days off-script for three Egyptian journalists',
#   'date': '12 12 2022'},
#  {'header': "‘How the fuck is it possible?': Russian rapper releases anti-war album",
#   'date': '12 12 2022'},
#  {'header': 'Azerbaijan arrests prominent political activist ahead of International Human Rights Day',
#   'date': '12 12 2022'},
#  {'header': 'Undertones in Pakistan: Military, Women, Blasphemy',
#   'date': '12 12 2022'},
#  {'header': 'Australian PM Anthony Albanese adds to growing political pressure to #FreeJulianAssange',
#   'date': '12 12 2022'},
#  {'header': 'A Caribbean debrief of COP27 that goes beyond the historic loss and damage fund',
#   'date': '11 12 2022'},
#  {'header': 'In defense of whom? Protesting Jordan’s perpetual state of emergency',
#   'date': '11 12 2022'},
#  {'header': 'Latin Americans still invest in cryptocurrency despite crisis',
#   'date': '10 12 2022'},
#  {'header': 'Does Messi speak Spanish or ‘Argentine’?', 'date': '9 12 2022'},
#  {'header': 'How is the Caribbean faring on International Anti-Corruption Day?',
#   'date': '9 12 2022'},
#  {'header': 'Breaking the binary of trauma and resilience in mental health: Interview with Lamia Moghnieh',
#   'date': '9 12 2022'},
#  {'header': 'In Turkey, a child bride scandal puts religious cults in the spotlight',
#   'date': '9 12 2022'},
#  {'header': 'The last of the Tharu traditional healers of Nepal',
#   'date': '8 12 2022'},
#  {'header': 'China faces a rough road to ending its zero-COVID policies',
#   'date': '8 12 2022'},
#  {'header': 'How the Venezuelan government uses social media to cover up its biggest corruption case',
#   'date': '8 12 2022'},
#  {'header': 'These culturally conscious African fashion designers are leading another sportswear revolution',
#   'date': '8 12 2022'},
#  {'header': 'State capture in South Africa by the Gupta family: A lesson on political influence',
#   'date': '7 12 2022'},
#  {'header': 'Freedom of expression in Tanzania is on a downward spiral',
#   'date': '6 12 2022'},
#  {'header': "New report: Framing China's Belt and Road Initiative",
#   'date': '5 12 2022'},
#  {'header': 'Global Voices is on Mastodon (and back on Tumblr)!',
#   'date': '5 12 2022'},
#  {'header': 'Popular TikToker Nekoglai tells of torture by Russian police',
#   'date': '5 12 2022'},
#  {'header': 'Activists strive for data protection in Indonesia',
#   'date': '5 12 2022'},
#  {'header': 'Twitter account “No Context Russia” is sad yet hilarious',
#   'date': '3 12 2022'},
#  {'header': "It's the  International Day of Persons with Disabilities, but in Trinidad & Tobago, ‘barriers remain in place’",
#   'date': '3 12 2022'},
#  {'header': 'Khodanoor Lajaei: Icon for a revolution', 'date': '2 12 2022'},
#  {'header': 'Nigerian student arrested after calling First Lady ‘fat from corruption’ on Twitter',
#   'date': '2 12 2022'},
#  {'header': 'China’s foreign interference narrative fails to successfully demonize the nationwide anti-zero COVID protests',
#   'date': '1 12 2022'},
#  {'header': '‘In Ecuador, disinformation has spread like a fungus,’ says Ecuadorian investigative journalist',
#   'date': '1 12 2022'},
#  {'header': 'Nepali migrant workers who built the World Cup stadiums are completely forgotten',
#   'date': '1 12 2022'},
#  {'header': "Istanbul's Uyghur community protest outside the Chinese Consulate despite the cost of reprisals",
#   'date': '1 12 2022'},
#  {'header': 'Soaring food prices and funding shortfalls add to growing food insecurity in Uganda’s refugee settlements',
#   'date': '1 12 2022'},
#  {'header': 'Cry me a river: Trinidad faces more serious flooding and anguish',
#   'date': '30 11 2022'},
#  {'header': 'President Erdoğan is on a mission to mend ties but at what cost?',
#   'date': '30 11 2022'},
#  {'header': 'Mexican collective pirating books to make culture accessible is blocked',
#   'date': '30 11 2022'},
#  {'header': 'A viral video of a dog abused at a shelter reveals a polarized Turkey',
#   'date': '29 11 2022'},
#  {'header': 'In Turkey, social media platforms become complicit in censoring media and freedom of speech',
#   'date': '29 11 2022'},
#  {'header': 'Global Voices seeks an editor to lead our Ukraine coverage',
#   'date': '28 11 2022'},
#  {'header': 'China’s zero-COVID policy sparks rare country-wide protests',
#   'date': '28 11 2022'},
#  {'header': '‘I am not returning to this hell’: In the Russian North Caucasus, NGOs help victims of gender and LGBTQ+ violence to escape',
#   'date': '28 11 2022'},
#  {'header': 'China in Uzbek media: Friend or foe?', 'date': '28 11 2022'},
#  {'header': 'Undertones: Twitter is a double-edged sword for the Global South',
#   'date': '28 11 2022'},
#  {'header': "Bolsonaro and his supporters continue to undermine democracy after losing Brazil's election",
#   'date': '28 11 2022'},
#  {'header': "Rare street protests across China: Is Xi Jinping's zero-COVID policy turning people against their government?",
#   'date': '27 11 2022'},
#  {'header': 'Released foreigners share their prison experiences in Myanmar',
#   'date': '27 11 2022'},
#  {'header': 'Why are Jamaicans crazy about Brazilian football?',
#   'date': '27 11 2022'},
#  {'header': 'Trinidad & Tobago placed under a ‘weather emergency’ alert',
#   'date': '26 11 2022'},
#  {'header': 'What role does the Chinese government play in the latest Foxconn workers protest?',
#   'date': '25 11 2022'},
#  {'header': 'Explaining the 20th Congress of the Communist Party of China: Culture and civilization',
#   'date': '25 11 2022'},
#  {'header': "In darkness but #withoutyou: How Moldova survives power cuts caused by Russia's bombing of Ukraine",
#   'date': '25 11 2022'},
#  {'header': 'Turkey marks International Day for the Elimination of Violence against women with disturbing femicide numbers',
#   'date': '25 11 2022'},
#  {'header': 'Brazil’s 2022 elections seen from Angola and Mozambique',
#   'date': '25 11 2022'},
#  {'header': 'With the US intervention, Kosovo and Serbia resolve the car license plate dispute',
#   'date': '25 11 2022'}]

# %%
 import pandas as pd
df = pd.DataFrame(articles_list)
df.head()
# Out:
#                                               header        date
# 0  France's institutional fear of multilingualism...  30 12 2022
# 1  European Parliament’s Report on Pegasus spywar...  29 12 2022
# 2  Welcome the new year with these joyful traditi...  29 12 2022
# 3  A Buryat voice calling on Russia to decolonize...  29 12 2022
# 4  The year in review: What the Caribbean looked ...  29 12 2022
